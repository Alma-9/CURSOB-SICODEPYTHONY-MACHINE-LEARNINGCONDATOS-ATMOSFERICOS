# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
# Out:
# /var/folders/6p/mnmjq8yn76gc57ppgmkyg4rr0000gn/T/ipykernel_17231/1617080438.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data=pd.read_csv("https://raw.githubusercontent.com/jamc88/Analisis-datos-atmosfericos/refs/heads/main/datos/rama_2023_05.csv")

# %%
data
# Out:
#            fecha        CO         NO        NO2        NOX         O3  \
# 0     2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150
# 1     2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366
# 2     2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486
# 3     2015-01-04  0.726940  24.606272  19.560976  44.165505  17.329032
# 4     2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588
# ...          ...       ...        ...        ...        ...        ...
# 3068  2023-05-27  0.256722   3.750583  17.284351  21.629371  41.580645
# 3069  2023-05-28  0.286826   3.458886  16.349241  20.230769  36.913761
# 3070  2023-05-29  0.482077  11.448113  24.521154  36.436321  29.697068
# 3071  2023-05-30  0.441455  13.893519  22.615530  37.224537  36.185971
# 3072  2023-05-31  0.340404   5.353066  19.372583  25.710359  47.860972
#
#             PM10       PM25        SO2
# 0     105.573684  78.953405  11.554723
# 1      36.687845  15.449438   1.895052
# 2      29.269022  12.915129   1.436937
# 3      39.961538  16.838284   1.809061
# 4      31.855643  12.667774   8.315789
# ...          ...        ...        ...
# 3068   36.774011  21.170139   2.735683
# 3069   28.580000  18.454861   2.331658
# 3070   30.241486  16.692857   1.071588
# 3071   35.859532  20.888525   1.181818
# 3072   42.203390  24.787097   1.402083
#
# [3073 rows x 9 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
X=data[['NO','PM25']]
y=data['PM10'] #variable objetivo

# %%
split_index=int(len(data)*0.8)
X_train=X.iloc[:split_index]
X_test=X.iloc[split_index:]
y_train=y.iloc[:split_index]
y_test=y.iloc[split_index:]

# %%
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.fit_transform(X_test)

# %%
svr_model=SVR(kernel='rbf', C=1.0, epsilon=0.1)
svr_model.fit(X_train_scaled, y_train)
# Out:
# SVR()

# %%
y_test_pred=svr_model.predict(X_test_scaled)

# %%
y_test_pred
# Out:
# array([27.81932313, 38.92844614, 34.56837793, 22.16472845, 31.79195536,
#        45.61082094, 41.0478599 , 29.04956361, 41.62171805, 24.49346423,
#        18.95603182, 19.63240016, 20.23969656, 27.86597995, 25.40213495,
#        36.7990967 , 19.09899338, 35.95045898, 34.00059886, 37.68457419,
#        44.36681809, 35.40823799, 20.74233609, 24.44633886, 29.88115835,
#        35.60263634, 56.11061658, 19.79497998, 19.84911712, 42.55897288,
#        20.20574119, 45.49187087, 41.59355912, 30.07780554, 53.30693609,
#        60.58943916, 48.52545462, 39.45613297, 39.63103423, 31.66984001,
#        46.91502724, 47.01040142, 41.9103673 , 36.28756035, 25.86993265,
#        39.87345194, 53.84967418, 55.20213032, 40.86877037, 28.93114358,
#        26.81053463, 27.81702727, 25.21388193, 43.9781942 , 46.97148385,
#        46.68731677, 21.20018152, 27.90896037, 34.35576964, 29.1248349 ,
#        21.38411097, 39.41333524, 58.8535435 , 36.98945694, 58.59522874,
#        63.3623377 , 28.2855084 , 50.25860054, 55.00910713, 71.73551194,
#        71.13879728, 63.16405348, 71.45044144, 74.33176583, 58.15666189,
#        45.78219519, 33.02115553, 30.4234597 , 57.00880819, 48.06340273,
#        51.77882864, 48.7863134 , 50.86859821, 63.07265854, 54.78857187,
#        55.03108662, 51.76814621, 33.68869071, 46.30792393, 30.27355463,
#        36.47351067, 58.84189998, 61.32557381, 54.36230343, 57.33636821,
#        39.48620144, 51.07153283, 48.36435042, 37.73686248, 35.27225869,
#        44.39146817, 56.58567432, 40.79331874, 26.60730687, 46.07480953,
#        38.64126562, 25.49733272, 51.58700933, 53.18583346, 47.76896169,
#        37.38910985, 41.32031769, 50.87857089, 53.93099894, 53.59115832,
#        45.04571323, 46.95886049, 47.79141527, 48.46638877, 47.51549651,
#        52.02293562, 50.03594088, 52.13373432, 54.64613649, 40.38591293,
#        38.33021023, 40.62317165, 33.03191071, 27.23761996, 33.62824056,
#        25.15679517, 36.51296562, 24.52296444, 34.68004302, 46.50334446,
#        37.32071413, 47.84896966, 54.93708406, 55.35651169, 61.65520174,
#        56.93929255, 52.79635308, 44.35288676, 56.68882578, 54.46019161,
#        53.15042581, 56.1164338 , 57.37464629, 56.0956657 , 52.46894388,
#        38.46176489, 46.8828337 , 38.20807458, 36.0372843 , 28.36041104,
#        20.90416676, 28.50483751, 41.6127996 , 37.27083317, 34.06836265,
#        30.63245225, 38.62446135, 48.75111531, 51.35799056, 34.97265356,
#        34.68449508, 33.57107076, 36.35397282, 31.03970895, 48.87595176,
#        68.82738001, 49.49885328, 49.7974616 , 42.60623964, 43.37877615,
#        52.67913107, 64.15197383, 59.95796015, 65.37657956, 63.63724197,
#        39.39372592, 36.01130058, 42.3343077 , 50.18619146, 55.40132529,
#        52.45067393, 46.40609504, 35.28959299, 24.41296608, 45.37047222,
#        49.78190319, 43.53723637, 48.00147997, 43.62983542, 31.82381853,
#        46.13416304, 57.19380873, 48.46055659, 48.99878666, 38.95700268,
#        40.57377546, 34.8883643 , 33.02397624, 43.16184882, 48.76845226])

# %%
test_mse=mean_squared_error(y_test,y_test_pred)
test_r2=r2_score(y_test,y_test_pred)

# %%
test_mse  #error cuadratico medio
# Out:
# 56.02220213017183

# %%
test_r2   #coeficiente de determinacion
# Out:
# 0.7253648621457018

# %%
plt.figure(figsize=(12,6))
plt.plot(data.iloc[split_index:]['fecha'].to_numpy(), y_test,label='valores reales',color='green')
plt.plot(data.iloc[split_index:]['fecha'].to_numpy(), y_test_pred,label='predicciones',color='red')
plt.xlabel('Fecha')
plt.ylabel('PM10')
plt.legend()
plt.xticks(data.iloc[split_index:]['fecha'][::15],rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b1476121ab89> in <module>
# ----> 1 plt.figure(figsize=(12,6))
#       2 plt.plot(data.iloc[split_index:]['fecha'].to_numpy(), y_test,label='valores reales',color='green')
#       3 plt.plot(data.iloc[split_index:]['fecha'].to_numpy(), y_test_pred,label='predicciones',color='red')
#       4 plt.xlabel('Fecha')
#       5 plt.ylabel('PM10')
#
# NameError: name 'plt' is not defined

# %%
fechas = data.iloc[split_index:]['fecha']  
y_test = y_test  
y_test_pred = y_test_pred  


print(f"Fechas: {len(fechas)}, Valores reales: {len(y_test)}, Predicciones: {len(y_test_pred)}")


import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(fechas, y_test, label='Valores Reales', linestyle='-', color='blue')
plt.plot(fechas, y_test_pred, label='Predicciones', linestyle='--', color='red')
plt.title('Valores Reales vs Predicciones')
plt.xlabel('Fecha')
plt.ylabel('CO')
plt.legend()

plt.show()
# Out:
# Fechas: 615, Valores reales: 615, Predicciones: 615

# %%
plt.figure(figsize=(12,6))
plt.scatter(y_test,y_test_pred,color='blue')
plt.plot([y_test.min(),y_test.max()],[y_test.min(),y_test.max()],"r--",label='linea ideal')
plt.title('valores predictivos vs reales')
plt.xlabel('valores reales')
plt.ylabel('valores predichos')
# Out:
# Text(0, 0.5, 'valores predichos')

# %%
data['fecha']=pd.to_datetime(data['fecha'])

# %%
data['mes']=data['fecha'].dt.month

# %%
data['dia']=data['fecha'].dt.day

# %%
data['dia_de_semana']=data['fecha'].dt.dayofweek

# %%
data['fin_de_semana']=(data['fecha'].dt.dayofweek>=5).astype(int)

# %%
data
# Out:
#           fecha        CO         NO        NO2        NOX         O3  \
# 0    2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150
# 1    2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366
# 2    2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486
# 3    2015-01-04  0.726940  24.606272  19.560976  44.165505  17.329032
# 4    2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588
# ...         ...       ...        ...        ...        ...        ...
# 3068 2023-05-27  0.256722   3.750583  17.284351  21.629371  41.580645
# 3069 2023-05-28  0.286826   3.458886  16.349241  20.230769  36.913761
# 3070 2023-05-29  0.482077  11.448113  24.521154  36.436321  29.697068
# 3071 2023-05-30  0.441455  13.893519  22.615530  37.224537  36.185971
# 3072 2023-05-31  0.340404   5.353066  19.372583  25.710359  47.860972
#
#             PM10       PM25        SO2  mes  dia  dia_de_semana  fin_de_semana
# 0     105.573684  78.953405  11.554723    1    1              3              0
# 1      36.687845  15.449438   1.895052    1    2              4              0
# 2      29.269022  12.915129   1.436937    1    3              5              1
# 3      39.961538  16.838284   1.809061    1    4              6              1
# 4      31.855643  12.667774   8.315789    1    5              0              0
# ...          ...        ...        ...  ...  ...            ...            ...
# 3068   36.774011  21.170139   2.735683    5   27              5              1
# 3069   28.580000  18.454861   2.331658    5   28              6              1
# 3070   30.241486  16.692857   1.071588    5   29              0              0
# 3071   35.859532  20.888525   1.181818    5   30              1              0
# 3072   42.203390  24.787097   1.402083    5   31              2              0
#
# [3073 rows x 13 columns]

# %%
data.head(25)
# Out:
#         fecha        CO         NO        NO2        NOX         O3  \
# 0  2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150
# 1  2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366
# 2  2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486
X=data.drop(columns=['fecha','PM10'])

# %%
X
# Out:
#             CO         NO        NO2        NOX         O3       PM25  \
# 0     1.050696  22.765528  24.225155  46.987578  23.175150  78.953405
# 1     0.807585  32.249608  21.554160  53.800628  17.268366  15.449438
# 2     0.640755  21.686916  19.394081  41.071651  15.486486  12.915129
# 3     0.726940  24.606272  19.560976  44.165505  17.329032  16.838284
# 4     0.530815  11.443182  20.990260  32.439935  14.470588  12.667774
# ...        ...        ...        ...        ...        ...        ...
# 3068  0.256722   3.750583  17.284351  21.629371  41.580645  21.170139
# 3069  0.286826   3.458886  16.349241  20.230769  36.913761  18.454861
# 3070  0.482077  11.448113  24.521154  36.436321  29.697068  16.692857
# 3071  0.441455  13.893519  22.615530  37.224537  36.185971  20.888525
# 3072  0.340404   5.353066  19.372583  25.710359  47.860972  24.787097
#
#             SO2  mes  dia  dia_de_semana  fin_de_semana
# 0     11.554723    1    1              3              0
# 1      1.895052    1    2              4              0
# 2      1.436937    1    3              5              1
# 3      1.809061    1    4              6              1
# 4      8.315789    1    5              0              0
# ...         ...  ...  ...            ...            ...
# 3068   2.735683    5   27              5              1
# 3069   2.331658    5   28              6              1
# 3070   1.071588    5   29              0              0
# 3071   1.181818    5   30              1              0
# 3072   1.402083    5   31              2              0
#
# [3073 rows x 11 columns]

# %%
y=data['PM10']

# %%
selector=SelectKBest(score_func=f_regression,k=8)
X_selected=selector.fit_transform(X,y)

# %%
X_selected
# Out:
# array([[ 1.05069583, 22.76552795, 24.22515528, ..., 78.95340502,
#         11.55472264,  1.        ],
#        [ 0.80758483, 32.24960754, 21.55416013, ..., 15.4494382 ,
#          1.89505247,  1.        ],
#        [ 0.64075547, 21.68691589, 19.394081  , ..., 12.91512915,
#          1.43693694,  1.        ],
#        ...,
#        [ 0.48207721, 11.44811321, 24.52115385, ..., 16.69285714,
#          1.07158837,  5.        ],
#        [ 0.44145455, 13.89351852, 22.6155303 , ..., 20.88852459,
#          1.18181818,  5.        ],
#        [ 0.34040367,  5.35306554, 19.37258348, ..., 24.78709677,
#          1.40208333,  5.        ]])

# %%
selected_features=X.columns[selector.get_support()]

# %%
selected_features
# Out:
# Index(['CO', 'NO', 'NO2', 'NOX', 'O3', 'PM25', 'SO2', 'mes'], dtype='object')

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model=RandomForestRegressor(random_state=42)

# %%
rf_model.fit(X,y)
# Out:
# RandomForestRegressor(random_state=42)

# %%
importancia_df=pd.DataFrame({'Caracteristica':X.columns,'Importancia': rf_model.feature_importances_}).sort_values(by='Importancia',ascending=False)

# %%
importancia_df
# Out:
#    Caracteristica  Importancia
# 5            PM25     0.757325
# 7             mes     0.079192
# 2             NO2     0.030303
# 4              O3     0.029657
# 3             NOX     0.027069
# 1              NO     0.025222
# 6             SO2     0.016472
# 0              CO     0.014494
# 8             dia     0.011937
# 9   dia_de_semana     0.007100
# 10  fin_de_semana     0.001229

# %%
redmet=pd.read_csv("https://raw.githubusercontent.com/jamc88/Analisis-datos-atmosfericos/refs/heads/main/datos/redmet_2023_05.csv")

# %%
redmet
# Out:
#            fecha         RH        TMP         WDR       WSP
# 0     2015-01-01  60.565476  13.385714  156.723039  1.933333
# 1     2015-01-02  52.452381  13.567262  176.710784  2.559804
# 2     2015-01-03  55.763636  13.893333  190.830846  2.136318
# 3     2015-01-04  62.776786  12.536012  196.306373  2.592647
# 4     2015-01-05  70.271845   9.070227  266.889764  2.963517
# ...          ...        ...        ...         ...       ...
# 3068  2023-05-27  51.899130  19.453565  190.198664  2.187646
# 3069  2023-05-28  59.949565  17.375826  183.542571  2.092154
# 3070  2023-05-29  58.837743  17.039153  169.527919  1.952284
# 3071  2023-05-30  50.145719  18.684699  184.998255  1.978709
# 3072  2023-05-31  50.353261  20.089130  172.697917  1.962153
#
# [3073 rows x 5 columns]

# %%
redmet['fecha']=pd.to_datetime(redmet['fecha'])

# %%
data['fecha']=pd.to_datetime(data['fecha'])

# %%
union=pd.merge(data,redmet,on='fecha',how='inner')

# %%
union
# Out:
#           fecha        CO         NO        NO2        NOX         O3  \
# 0    2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150
# 1    2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366
# 2    2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486
# 3    2015-01-04  0.726940  24.606272  19.560976  44.165505  17.329032
# 4    2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588
# ...         ...       ...        ...        ...        ...        ...
# 3068 2023-05-27  0.256722   3.750583  17.284351  21.629371  41.580645
# 3069 2023-05-28  0.286826   3.458886  16.349241  20.230769  36.913761
# 3070 2023-05-29  0.482077  11.448113  24.521154  36.436321  29.697068
# 3071 2023-05-30  0.441455  13.893519  22.615530  37.224537  36.185971
# 3072 2023-05-31  0.340404   5.353066  19.372583  25.710359  47.860972
#
#             PM10       PM25        SO2  mes  dia  dia_de_semana  \
# 0     105.573684  78.953405  11.554723    1    1              3
# 1      36.687845  15.449438   1.895052    1    2              4
# 2      29.269022  12.915129   1.436937    1    3              5
# 3      39.961538  16.838284   1.809061    1    4              6
# 4      31.855643  12.667774   8.315789    1    5              0
# ...          ...        ...        ...  ...  ...            ...
# 3068   36.774011  21.170139   2.735683    5   27              5
# 3069   28.580000  18.454861   2.331658    5   28              6
# 3070   30.241486  16.692857   1.071588    5   29              0
# 3071   35.859532  20.888525   1.181818    5   30              1
# 3072   42.203390  24.787097   1.402083    5   31              2
#
#       fin_de_semana         RH        TMP         WDR       WSP
# 0                 0  60.565476  13.385714  156.723039  1.933333
# 1                 0  52.452381  13.567262  176.710784  2.559804
# 2                 1  55.763636  13.893333  190.830846  2.136318
# 3                 1  62.776786  12.536012  196.306373  2.592647
# 4                 0  70.271845   9.070227  266.889764  2.963517
# ...             ...        ...        ...         ...       ...
# 3068              1  51.899130  19.453565  190.198664  2.187646
# 3069              1  59.949565  17.375826  183.542571  2.092154
# 3070              0  58.837743  17.039153  169.527919  1.952284
# 3071              0  50.145719  18.684699  184.998255  1.978709
# 3072              0  50.353261  20.089130  172.697917  1.962153
#
# [3073 rows x 17 columns]
